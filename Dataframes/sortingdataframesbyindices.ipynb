# %%
import pandas as pd

# %%
#sort a dataframe by its indices using the .sort_index() method
#

# %%
import pandas as pd

oil = pd.read_csv("../retail/oil.csv",
                 parse_dates=['date']
                 )
oil['benchmark'] = 100
oil.head()
# Out:
#         date  dcoilwtico  benchmark
# 0 2013-01-01         NaN        100
# 1 2013-01-02       93.14        100
# 2 2013-01-03       92.97        100
# 3 2013-01-04       93.12        100
# 4 2013-01-07       93.20        100

# %%
oil
# Out:
#            date  dcoilwtico  benchmark
# 0    2013-01-01         NaN        100
# 1    2013-01-02       93.14        100
# 2    2013-01-03       92.97        100
# 3    2013-01-04       93.12        100
# 4    2013-01-07       93.20        100
# ...         ...         ...        ...
# 1213 2017-08-25       47.65        100
# 1214 2017-08-28       46.40        100
# 1215 2017-08-29       46.46        100
# 1216 2017-08-30       45.96        100
# 1217 2017-08-31       47.26        100
#
# [1218 rows x 3 columns]

# %%
oil.sort_index(ascending=True, axis=1)
# Out:
#       benchmark       date  dcoilwtico
# 0           100 2013-01-01         NaN
# 1           100 2013-01-02       93.14
# 2           100 2013-01-03       92.97
# 3           100 2013-01-04       93.12
# 4           100 2013-01-07       93.20
# ...         ...        ...         ...
# 1213        100 2017-08-25       47.65
# 1214        100 2017-08-28       46.40
# 1215        100 2017-08-29       46.46
# 1216        100 2017-08-30       45.96
# 1217        100 2017-08-31       47.26
#
# [1218 rows x 3 columns]

# %%
oil["month"] = oil["date"].astype("Datetime64").dt.month

oil
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 oil["month"] = oil["date"].astype("Datetime64").dt.month
#       3 oil
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
oil.sort_values("dcoilwtico", ascending=True)
# Out:
#            date  dcoilwtico  benchmark
# 812  2016-02-11       26.19        100
# 796  2016-01-20       26.68        100
# 811  2016-02-10       27.54        100
# 810  2016-02-09       27.96        100
# 795  2016-01-19       28.47        100
# ...         ...         ...        ...
# 1079 2017-02-20         NaN        100
# 1118 2017-04-14         NaN        100
# 1149 2017-05-29         NaN        100
# 1174 2017-07-03         NaN        100
# 1175 2017-07-04         NaN        100
#
# [1218 rows x 3 columns]

# %%
# oil.sort_values(['month', "dcoilwtico"], ascending=[True, False])
